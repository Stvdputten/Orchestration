# %%
# !rm df-*-checkpoint.csv
# Out:
# zsh:1: no matches found: df-*-checkpoint.csv

# %%
import os
import glob

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load all datasets

# %%
all_files = glob.glob("*exp*-*.csv")
df = pd.concat((pd.read_csv(f) for f in all_files))
df = df.drop_duplicates()
print(df.shape)
# Out:
# (1220, 20)

# %%
df['Exp']
# Out:
# 0     exp15
# 1     exp15
# 2     exp15
# 3     exp15
# 4     exp15
#       ...
# 65    exp14
# 66    exp14
# 67    exp14
# 68    exp14
# 69    exp14
# Name: Exp, Length: 1220, dtype: object

# %%
df['Exp'].astype('category').cat.remove_unused_categories()
# Out:
# 0     exp15
# 1     exp15
# 2     exp15
# 3     exp15
# 4     exp15
#       ...
# 65    exp14
# 66    exp14
# 67    exp14
# 68    exp14
# 69    exp14
# Name: Exp, Length: 1220, dtype: category
# Categories (4, object): ['exp12', 'exp13', 'exp14', 'exp15']

# %%
df['Orchestrator'] = df['Orchestrator'].astype('category')
df['Benchmark'] = df['Benchmark'].astype('category')

df['Exp'] = df['Exp'].astype('category')
# df['Latency'] = df['Latency']
df['Requests'] = df['Requests'].astype(int)

# %%
df_0 = df.loc[df['Exp'] == 'exp0']
df_1 = df.loc[df['Exp'] == 'exp1']
df_2 = df.loc[df['Exp'] == 'exp2']
df_3 = df.loc[df['Exp'] == 'exp3']
df_4 = df.loc[df['Exp'] == 'exp4']
df_5 = df.loc[df['Exp'] == 'exp5']
df_6 = df.loc[df['Exp'] == 'exp6']
df_7 = df.loc[df['Exp'] == 'exp7']
df_8 = df.loc[df['Exp'] == 'exp8']
df_9 = df.loc[df['Exp'] == 'exp9']
df_10 = df.loc[df['Exp'] == 'exp10']
df_11 = df.loc[df['Exp'] == 'exp11']

# %%
df_12 = df.loc[(df['Exp'] == 'exp12')]
df_13 = df.loc[(df['Exp'] == 'exp13')]
df_14 = df.loc[(df['Exp'] == 'exp14')]
df_15 = df.loc[(df['Exp'] == 'exp15')]
df_all_orch = pd.concat([df_12, df_13, df_14, df_15])
df_all_orch['Exp'] = df_all_orch['Exp'].cat.remove_unused_categories()
df_12_swarm = df.loc[(df['Exp'] == 'exp12') & (df['Orchestrator'] == 'swarm')]
df_13_swarm = df.loc[(df['Exp'] == 'exp13') & (df['Orchestrator'] == 'swarm')]
df_14_swarm = df.loc[(df['Exp'] == 'exp14') & (df['Orchestrator'] == 'swarm')]
df_15_swarm = df.loc[(df['Exp'] == 'exp15') & (df['Orchestrator'] == 'swarm')]
df_12_nomad = df.loc[(df['Exp'] == 'exp12') & (df['Orchestrator'] == 'nomad')]
df_13_nomad = df.loc[(df['Exp'] == 'exp13') & (df['Orchestrator'] == 'nomad')]
df_14_nomad = df.loc[(df['Exp'] == 'exp14') & (df['Orchestrator'] == 'nomad')]
df_15_nomad = df.loc[(df['Exp'] == 'exp15') & (df['Orchestrator'] == 'nomad')]
df_12_k8s = df.loc[(df['Exp'] == 'exp12') & (df['Orchestrator'] == 'k8s')]
df_13_k8s = df.loc[(df['Exp'] == 'exp13') & (df['Orchestrator'] == 'k8s')]
df_14_k8s = df.loc[(df['Exp'] == 'exp14') & (df['Orchestrator'] == 'k8s')]
df_15_k8s = df.loc[(df['Exp'] == 'exp15') & (df['Orchestrator'] == 'k8s')]

# %%
# Global settings
fontsize = 20
legend_location = "lower right"

# %% [markdown]
# # Exp12 Swarm

# %%
df_12.columns
# Out:
# Index(['Latency', 'Requests', 'Throughput', 'Measured_Throughput', 'Baseline',
#        'Orchestrator', 'Benchmark', 'Infinite', 'Exp', 'N', 'Availability',
#        'Horizontal', 'Vertical', 'Threads', 'Connections', 'Duration', 'Mean',
#        'Max', 'StdDev', 'ReqSec'],
#       dtype='object')

# %%
df_12_swarm.iloc[:,[0,1,2,5,4,3,9,-4,-3,-2,-1]]
# Out:
#       Latency  Requests  Throughput Orchestrator  Baseline  \
# 0        8.14       500     14720.0        swarm         0
# 1    10400.00       500     11276.0        swarm         0
# 2    14930.00       500      9847.0        swarm         0
# 3    13800.00       500     10269.0        swarm         0
# 4        8.31       500     14768.0        swarm         0
# ..        ...       ...         ...          ...       ...
# 100  25560.00     10000     43707.0        swarm         0
# 101  27740.00     10000     37232.0        swarm         0
# 102  28050.00     10000     21748.0        swarm         0
# 103  27670.00     10000     23996.0        swarm         0
# 104  28050.00     10000     26994.0        swarm         0
#
#      Measured_Throughput  N       Mean        Max    StdDev   ReqSec
# 0                   9862  3      2.561     12.616     1.730   490.21
# 1                   6358  3   3445.497  13705.216  2421.424   375.47
# ...

# %%
df_12_swarm
# Out:
#       Latency  Requests  Throughput  Measured_Throughput  Baseline  \
# 0        8.14       500     14720.0                 9862         0
# 1    10400.00       500     11276.0                 6358         0
# 2    14930.00       500      9847.0                 6589         0
# 3    13800.00       500     10269.0                 6620         0
# 4        8.31       500     14768.0                 9849         0
# ..        ...       ...         ...                  ...       ...
# 100  25560.00     10000     43707.0                28759         0
# 101  27740.00     10000     37232.0                24703         0
# 102  28050.00     10000     21748.0                14552         0
# 103  27670.00     10000     23996.0                15914         0
# 104  28050.00     10000     26994.0                18143         0
#
#     Orchestrator Benchmark  Infinite    Exp  N  Availability  Horizontal  \
# 0          swarm        hr         1  exp12  3             0           1
# ...

# %%
sns.catplot(data=df_12_swarm, x='Requests',  y='Latency', hue='Benchmark', kind="strip")

# %%
sns.catplot(data=df_12_k8s, x='Requests',  y='Latency', hue='Benchmark', kind="strip")

# %%
df_12_swarm_R500 = df.loc[(df['Exp'] == 'exp12') & (df['Orchestrator'] == 'swarm')]

# %%
df_12_swarm_R500 = df_12_swarm[(df_12_swarm['Requests'] == 500) & (df_12_swarm['Benchmark'] != 'mm')]

# %%
df_12_swarm_R500
# Out:
#     Latency  Requests  Throughput  Measured_Throughput  Baseline Orchestrator  \
# 0      8.14       500     14720.0                 9862         0        swarm
# 4      8.31       500     14768.0                 9849         0        swarm
# 5      8.22       500     14768.0                 9851         0        swarm
# 7      8.65       500     14828.0                 9842         0        swarm
# 8      8.19       500     14828.0                 9842         0        swarm
# 10     7.86       500     14825.0                 9845         0        swarm
# 11     7.10       500     14770.0                 9852         0        swarm
# 12     6.16       500     14826.0                 9842         0        swarm
# 13     6.47       500     14768.0                 9848         0        swarm
# 14     7.75       500     14827.0                 9843         0        swarm
#
#    Benchmark  Infinite    Exp  N  Availability  Horizontal  Vertical  Threads  \
# ...

# %%
df_12_swarm_R500
# Out:
#     Latency  Requests  Throughput  Measured_Throughput  Baseline Orchestrator  \
# 0      8.14       500     14720.0                 9862         0        swarm
# 4      8.31       500     14768.0                 9849         0        swarm
# 5      8.22       500     14768.0                 9851         0        swarm
# 7      8.65       500     14828.0                 9842         0        swarm
# 8      8.19       500     14828.0                 9842         0        swarm
# 10     7.86       500     14825.0                 9845         0        swarm
# 11     7.10       500     14770.0                 9852         0        swarm
# 12     6.16       500     14826.0                 9842         0        swarm
# 13     6.47       500     14768.0                 9848         0        swarm
# 14     7.75       500     14827.0                 9843         0        swarm
#
#    Benchmark  Infinite    Exp  N  Availability  Horizontal  Vertical  Threads  \
# ...

# %%
df_12_swarm[(df_12_swarm['Requests'] == 5000) & (df_12_swarm['Benchmark'] == 'mm')]
# Out:
#     Latency  Requests  Throughput  Measured_Throughput  Baseline Orchestrator  \
# 80  27750.0      5000     10494.0                 7284         0        swarm
# 81  27710.0      5000     10587.0                 7320         0        swarm
# 82  27790.0      5000     10513.0                 7241         0        swarm
# 83  27770.0      5000     10446.0                 7262         0        swarm
# 84  27840.0      5000     10498.0                 7261         0        swarm
#
#    Benchmark  Infinite    Exp  N  Availability  Horizontal  Vertical  Threads  \
# 80        mm         1  exp12  1             0           1         1        8
# 81        mm         1  exp12  2             0           1         1        8
# 82        mm         1  exp12  5             0           1         1        8
# 83        mm         1  exp12  4             0           1         1        8
# 84        mm         1  exp12  3             0           1         1        8
#
# ...

# %%
g = sns.catplot(data=df_12_swarm, x='Requests',  y='Measured_Throughput', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")
# Out:
#   Input In [112]
#     g.despine(left=True)
#     ^
# SyntaxError: invalid syntax

# %%
g = sns.catplot(data=df_13_swarm, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_14_swarm, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_15_swarm, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
df_12_k8s
# Out:
#       Latency  Requests  Throughput  Measured_Throughput  Baseline  \
# 0       11.76       500     14769.0                 9851         0
# 1       12.31       500     14719.0                 9861         0
# 2       12.29       500     14828.0                 9842         0
# 3       12.17       500     14828.0                 9843         0
# 4       11.83       500     14718.0                 9863         0
# ..        ...       ...         ...                  ...       ...
# 100  25120.00     10000     47535.0                32264         0
# 101  25540.00     10000     46476.0                30795         0
# 102  27310.00     10000     26710.0                18160         0
# 103  27260.00     10000     27646.0                18412         0
# 104  26800.00     10000     31489.0                20864         0
#
#     Orchestrator Benchmark  Infinite    Exp  N  Availability  Horizontal  \
# 0            k8s        hr         1  exp12  3             0           1
# ...

# %%
g = sns.catplot(data=df_12_k8s, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_13_k8s, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_14_k8s, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_15_k8s, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_12_nomad, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_13_nomad, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_14_nomad, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.catplot(data=df_15_nomad, x='Requests',  y='Latency', hue='Benchmark', kind="bar")
g.despine(left=True)
g.set_axis_labels("Requests", "Tail latency 99th perc% (ms)")

# %%
g = sns.relplot(data=df_12_k8s, x='Requests',  y='Latency', hue='Benchmark', kind='line', style='Benchmark')

# %%
g = sns.relplot(data=df_13_k8s, x='Requests',  y='Latency', hue='Benchmark', kind='line', style='Benchmark')

# %%
g = sns.relplot(data=df_14_k8s, x='Requests',  y='Latency', hue='Benchmark', kind='line', style='Benchmark')

# %%
g = sns.relplot(data=df_15_k8s, x='Requests',  y='Latency', hue='Benchmark', kind='line', style='Benchmark')

# %%
g = sns.relplot(data=df_12_swarm, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
df_12_swarm
# Out:
#       Latency  Requests  Throughput  Measured_Throughput  Baseline  \
# 0        8.14       500     14720.0                 9862         0
# 1    10400.00       500     11276.0                 6358         0
# 2    14930.00       500      9847.0                 6589         0
# 3    13800.00       500     10269.0                 6620         0
# 4        8.31       500     14768.0                 9849         0
# ..        ...       ...         ...                  ...       ...
# 100  25560.00     10000     43707.0                28759         0
# 101  27740.00     10000     37232.0                24703         0
# 102  28050.00     10000     21748.0                14552         0
# 103  27670.00     10000     23996.0                15914         0
# 104  28050.00     10000     26994.0                18143         0
#
#     Orchestrator Benchmark  Infinite    Exp  N  Availability  Horizontal  \
# 0          swarm        hr         1  exp12  3             0           1
# ...

# %%
g = sns.relplot(data=df_12_swarm, x='Latency',  y='Measured_Throughput', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_12_swarm, x='Requests',  y='Measured_Throughput', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_13_swarm, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_14_swarm, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_12_swarm, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_12_k8s, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_12_nomad, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
df_13_nomad
# Out:
#      Latency  Requests  Throughput  Measured_Throughput  Baseline  \
# 0   16720.00       500      8975.0                 6102         1
# 1       1.94       500     14666.0                 9865         1
# 2       1.98       500     14769.0                 9850         1
# 3       1.94       500     14831.0                 9845         1
# 4       1.96       500     14718.0                 9862         1
# ..       ...       ...         ...                  ...       ...
# 65  20140.00     10000    128370.0                81397         1
# 66  19450.00     10000    128755.0                82854         1
# 67  20090.00     10000    128471.0                80431         1
# 68  21690.00     10000    123963.0                82024         1
# 69  19790.00     10000    127624.0                81324         1
#
#    Orchestrator Benchmark  Infinite    Exp  N  Availability  Horizontal  \
# 0         nomad        mm         1  exp13  3             0           1
# ...

# %%
g = sns.relplot(data=df_13_nomad, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_14_nomad, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_15_nomad, x='Requests',  y='Latency', hue='Benchmark', kind='line')

# %%
g = sns.relplot(data=df_15_swarm, x='Requests',  y='Latency', hue='Benchmark', kind='line', style='Benchmark')

# %%
g = sns.relplot(data=df_15_nomad, x='Requests',  y='Latency', hue='Benchmark', kind='line')
