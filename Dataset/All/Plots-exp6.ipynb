# %%
# !rm df-*-checkpoint.csv
# Out:
# zsh:1: no matches found: df-*-checkpoint.csv

# %%
import os
import glob

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load all datasets

# %%
all_files = glob.glob("*.csv")
df = pd.concat((pd.read_csv(f) for f in all_files))
df = df.drop_duplicates()
print(df.shape)
# Out:
# (555, 18)

# %%
df['Orchestrator'] = df['Orchestrator'].astype('category')
df['Benchmark'] = df['Benchmark'].astype('category')
df['Exp'] = df['Exp'].astype('category')
# df['Latency'] = df['Latency']
df['Requests'] = df['Requests'].astype(int)

# %%
df_0 = df.loc[df['Exp'] == 'exp0']
df_1 = df.loc[df['Exp'] == 'exp1']
df_2 = df.loc[df['Exp'] == 'exp2']
df_3 = df.loc[df['Exp'] == 'exp3']
df_4 = df.loc[df['Exp'] == 'exp4']
df_5 = df.loc[df['Exp'] == 'exp5']
df_6 = df.loc[df['Exp'] == 'exp6']
df_7 = df.loc[df['Exp'] == 'exp7']
df_8 = df.loc[df['Exp'] == 'exp8']
df_9 = df.loc[df['Exp'] == 'exp9']
df_10 = df.loc[df['Exp'] == 'exp10']
df_11 = df.loc[df['Exp'] == 'exp11']

# %%
# Global settings
fontsize = 20
legend_location = "lower right"

# %% [markdown]
# # Exp6

# %%
df_6.iloc[:,[0,1,2,5,6,10,11,12,-1]].head()
# Out:
#    Latency  Requests  Throughput Benchmark  Infinite  Vertical  Threads  \
# 0     6.43      1500     43534.0        hr         1         1       16
# 1     6.73      1500     43591.0        sn         1         1       16
# 2     4.69      1500     43528.0        mm         1         1       16
# 3     4.47      1500     43457.0        mm         1         1        8
# 4     6.47      1500     44445.0        hr         1         1        8
#
#    Connections   ReqSec
# 0         1024  1450.22
# 1         1024  1451.00
# 2         1024  1450.00
# 3         1024  1447.07
# 4          512  1480.64

# %%
df_6.shape
# Out:
# (60, 18)

# %%
labels = df_6['Benchmark'].unique()

# %%
df_6
# Out:
#      Latency  Requests  Throughput  Baseline Orchestrator Benchmark  Infinite  \
# 0       6.43      1500     43534.0         0        swarm        hr         1
# 1       6.73      1500     43591.0         0        swarm        sn         1
# 2       4.69      1500     43528.0         0        swarm        mm         1
# 3       4.47      1500     43457.0         0        swarm        mm         1
# 4       6.47      1500     44445.0         0        swarm        hr         1
# 5       6.27      1500     44438.0         0        swarm        sn         1
# 6       4.62      1500     44194.0         0        swarm        mm         1
# 7       6.50      1500     43603.0         0        swarm        hr         1
# 8       6.52      1500     43763.0         0        swarm        sn         1
# 9       4.53      1500     44443.0         0        swarm        mm         1
# 10      6.42      1500     44304.0         0        swarm        hr         1
# 11      6.59      1500     44405.0         0        swarm        sn         1
# 12      7.60      2000     59464.0         0        swarm        sn         1
# 13  18020.00      2000     35319.0         0        swarm        sn         1
# 14      6.30      2000     58394.0         0        swarm        hr         1
# 15      5.98      2000     58271.0         0        swarm        mm         1
# 16   1290.00      2000     56216.0         0        swarm        sn         1
# 17      6.48      2000     59459.0         0        swarm        mm         1
# 18  20300.00      2000     38166.0         0        swarm        sn         1
# 19      6.42      2000     59486.0         0        swarm        hr         1
# 20      5.59      2000     58330.0         0        swarm        mm         1
# 21      6.44      2000     58540.0         0        swarm        hr         1
# 22      6.39      2000     59465.0         0        swarm        hr         1
# 23      5.80      2000     59739.0         0        swarm        mm         1
# 24  22220.00      2500     30720.0         0        swarm        sn         1
# 25      7.93      2500     73724.0         0        swarm        mm         1
# 26      8.28      2500     74610.0         0        swarm        mm         1
# 27      8.01      2500     74904.0         0        swarm        mm         1
# 28      7.61      2500     73111.0         0        swarm        mm         1
# 29  22460.00      2500     29775.0         0        swarm        sn         1
# 30      6.51      2500     74590.0         0        swarm        hr         1
# 31      6.59      2500     73448.0         0        swarm        hr         1
# 32      6.96      2500     74764.0         0        swarm        hr         1
# 33  24360.00      2500     34000.0         0        swarm        sn         1
# 34      6.99      2500     73244.0         0        swarm        hr         1
# 35  24310.00      2500     32126.0         0        swarm        sn         1
# 36     10.35      3000     89524.0         0        swarm        mm         1
# 37  24080.00      3000     26604.0         0        swarm        sn         1
# 38  23990.00      3000     27874.0         0        swarm        sn         1
# 39  23410.00      3000     29532.0         0        swarm        sn         1
# 40     10.64      3000     89710.0         0        swarm        mm         1
# 41     10.61      3000     88010.0         0        swarm        mm         1
# 42      6.84      3000     89542.0         0        swarm        hr         1
# 43      6.76      3000     88569.0         0        swarm        hr         1
# 44      6.88      3000     89346.0         0        swarm        hr         1
# 45      6.77      3000     87910.0         0        swarm        hr         1
# 46     12.43      3000     87851.0         0        swarm        mm         1
# 47  24100.00      3000     28408.0         0        swarm        sn         1
# 48  25100.00      3500     25214.0         0        swarm        sn         1
# 49     16.90      3500    104574.0         0        swarm        mm         1
# 50  25100.00      3500     24579.0         0        swarm        sn         1
# 51     18.38      3500    104948.0         0        swarm        mm         1
# 52     20.59      3500    102566.0         0        swarm        mm         1
# 53     25.33      3500    102816.0         0        swarm        mm         1
# 54      6.88      3500    104173.0         0        swarm        hr         1
# 55      6.92      3500    103018.0         0        swarm        hr         1
# 56     24.37      3500    104784.0         0        swarm        hr         1
# 57      6.93      3500    102460.0         0        swarm        hr         1
# 58  24870.00      3500     26122.0         0        swarm        sn         1
# 59  25850.00      3500     26456.0         0        swarm        sn         1
#
#      Exp  Availability  Horizontal  Vertical  Threads  Connections  Duration  \
# 0   exp6             0           1         1       16         1024        30
# 1   exp6             0           1         1       16         1024        30
# 2   exp6             0           1         1       16         1024        30
# 3   exp6             0           1         1        8         1024        30
# 4   exp6             0           1         1        8          512        30
# 5   exp6             0           1         1        8          512        30
# 6   exp6             0           1         1       16          512        30
# 7   exp6             0           1         1        8         1024        30
# 8   exp6             0           1         1        8         1024        30
# 9   exp6             0           1         1        8          512        30
# 10  exp6             0           1         1       16          512        30
# 11  exp6             0           1         1       16          512        30
# 12  exp6             0           1         1        8          512        30
# 13  exp6             0           1         1       16         1024        30
# 14  exp6             0           1         1       16         1024        30
# 15  exp6             0           1         1       16         1024        30
# 16  exp6             0           1         1        8         1024        30
# 17  exp6             0           1         1        8          512        30
# 18  exp6             0           1         1       16          512        30
# 19  exp6             0           1         1       16          512        30
# 20  exp6             0           1         1        8         1024        30
# 21  exp6             0           1         1        8         1024        30
# 22  exp6             0           1         1        8          512        30
# 36      5.217     45.088     1.397  2984.17
# 37  13159.161  26836.992  5534.870   884.91
# 38  12866.929  27099.136  5264.018   927.40
# 39  11850.000  25509.888  6178.776   982.33
# 40      5.283     22.352     1.418  2988.87
# 41      5.382     38.176     1.400  2933.22
# 42      2.121     12.144     1.402  2984.29
# 43      2.091     17.760     1.386  2951.90
# 44      2.127     14.824     1.411  2975.06
# 45      2.087     12.960     1.387  2928.66
# 46      5.498     39.168     1.725  2928.61
# 47  10747.961  26836.992  5923.991   945.85
# 48  14555.696  28246.016  4671.925   840.43
# 49      7.119     45.632     2.628  3485.63
# 50  14693.305  26918.912  5205.456   818.03
# 51      7.165     41.376     2.854  3498.28
# 52      7.323     58.464     3.216  3418.74
# 53      8.595     66.112     4.220  3427.11
# 54      2.158     12.496     1.423  3471.90
# 55      2.134     14.304     1.417  3433.65
# 56      2.840    217.856     7.388  3491.78
# 57      2.136     15.320     1.424  3414.13
# 58  13126.926  26411.008  4945.829   869.78
# 59  12765.674  28786.688  5298.516   879.93

# %%
p.axes[0][0]
# Out:
# <AxesSubplot:xlabel='Requests', ylabel='Latency (milliseconds)'>

# %%
# fig, ax = plt.subplots(figsize=(8,8))
# plt.figure(1)
labels = ["sn", "mm", "hr"]

# p = sns.catplot(x="Requests", y="Latency", data=df_6, hue="Benchmark")
p = sns.catplot(x="Benchmark", y="Latency",data=df_6, order=["sn","mm","hr"], hue="Requests")

# p.legend(loc="center", fontsize=20)
p.set_xlabels('Requests', fontsize=15)
p.set_ylabels('Latency (milliseconds)', fontsize=15)
# p.axes.get_xticks()
xticks = [int(tick) for tick in p.axes[0][0].get_xticks()]
# plt.yticks(fontsize=15)
# plt.xticks(xticks, fontsize=15)
# plt.xlim(
plt.savefig("Figures/exp6-all-t8-t16-c512-c1024.png", bbox_inches='tight')

# %%
# fig, ax = plt.subplots(figsize=(8,8))
# plt.figure(1)
labels = ["sn", "mm", "hr"]

# p = sns.catplot(x="Requests", y="Latency", data=df_6, hue="Benchmark")
p = sns.catplot(x="Benchmark", y="Latency", row="Threads", col="Connections",data=df_6, order=["sn","mm","hr"], hue="Requests", legend="")

# p.legend(loc="center", fontsize=20)
p.set_xlabels('Requests', fontsize=15)
p.set_ylabels('Latency (milliseconds)', fontsize=15)
# p.axes.get_xticks()
xticks = [int(tick) for tick in p.axes[0][0].get_xticks()]
# yticks = [int(tick) for tick in p.axes[0][0].get_yticks()]

# p.set_yticklabels(, fontsize=15)
p.set_xticklabels(labels, fontsize=15)
p.axes[0][1].legend(title="Requests" ,fontsize=15)
# plt.xticks(xticks, fontsize=15)
# plt.remo
# plt.xlim(
plt.savefig("Figures/exp6-t8-t16-c512-c1024.png", bbox_inches='tight')

# %% [markdown]
# Best plot because hr and mm doesn't break between 3500 and 4000, which we also saw in exp5

# %%
# p = sns.catplot(x="Benchmark", y="Latency", data=df_6, hue="Requests")
# # p.legend(loc="center", fontsize=20)
# p.set_xticklabels('Requests', fontsize=15)
# p.set_ylabels('Latency (milliseconds)', fontsize=fontsize)

# %%
ax = sns.barplot(x='Requests', y='Latency', data=df_6, hue="Benchmark")
