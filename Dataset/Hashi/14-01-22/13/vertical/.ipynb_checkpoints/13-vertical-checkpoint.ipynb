# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/13/vertical
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/13/vertical/../Figures

# %%
# %env var=15
# %env var_name=vertical
# %env exp=exp13

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=nomad

# !pwd
# !echo

# what to copy
# !cp ../$orch-$sn-* .
# !cp ../$orch-$mm-* .
# !cp ../$orch-$hr-* .

# !for file in nomad-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15
# env: var_name=vertical
# env: exp=exp13
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=nomad
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/13/vertical
#
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R10000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R12000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R14000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R16000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R18000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R20000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R3000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R4000
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R500
# nomad-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R6000
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R1000
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R2000
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R3000
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R4000
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R500
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R5000
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R6000
# nomad-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R7000
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R10000
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R1500
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R15000
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R2000
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R20000
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R3000
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R4000
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R500
# nomad-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R5000

# %%
# print which params to include
# !for file in $orch-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in $orch-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in $orch-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# R10000
# R1500
# R15000
# R2000
# R20000
# R3000
# R4000
# R500
# R5000
# R1000
# R2000
# R3000
# R4000
# R500
# R5000
# R6000
# R7000
# R10000
# R12000
# R14000
# R16000
# R18000
# R20000
# R3000
# R4000
# R500
# R6000

# %%
# rename to param(s)
# !for file in $orch-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in $orch-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in $orch-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)$orch-$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$orch-$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$orch-$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/sn-vertical-exp13.png
# Wrote: ../Figures/mm-vertical-exp13.png
# Wrote: ../Figures/hr-vertical-exp13.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

for bench in ['sn','mm','hr']:
    filename=f"{location}{orch}-{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
