# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/13/vertical
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/13/vertical/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/13/vertical/../Figures'

# %%
# !cp ../nomad-* .
# !hdr-plot --save nomad-*

# %%
# %env var=15
# %env var_name=vertical
# %env exp=exp13

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=nomad

# !pwd
# !echo

# what to copy
# !cp ../$orch-$sn-* .
# !cp ../$orch-$mm-* .
# !cp ../$orch-$hr-* .

# !for file in nomad-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15
# env: var_name=vertical
# env: exp=exp13
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=nomad
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/13/vertical

# %%
# Overview of all
# %env var_name=t16-c512

# !hdr-plot --output $(echo $location)lat-$orch-$var_name-$exp.png --nobox --legend_location "upper left" --lat_req $orch-* --legend_fontsize 20
# Out:
# Multiple benchmarks but one param
# Wrote: ../Figures/lat-nomad-vertical-exp13.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

filename=f"{location}lat-{orch}-{var_name}-{exp}.png"
display(Image(filename=filename, retina=True))
