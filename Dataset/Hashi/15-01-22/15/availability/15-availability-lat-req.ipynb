# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Hashi/15-01-22/15/availability
# /Users/stvdputten/Documents/Thesis/Results/Hashi/15-01-22/15/availability/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Hashi/15-01-22/15/availability/../Figures'

# %%
# %env var=15
# %env var_name=availability
# %env exp=exp15

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=nomad

# !pwd
# !echo

# what to copy
# !cp ../$orch-$sn-* .
# !cp ../$orch-$mm-* .
# !cp ../$orch-$hr-* .

# !for file in nomad-* ; do echo $file; done
# Out:
# env: var=15
# env: var_name=availability
# env: exp=exp15
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=nomad
# /Users/stvdputten/Documents/Thesis/Results/Hashi/15-01-22/15/availability

# %%
# Overview of all
# !hdr-plot --output $(echo $location)lat-$orch-$var_name-$exp.png --nobox --legend_location "upper left" --lat_req $orch-* --legend_fontsize 20
# Out:
# Multiple benchmarks but one param
# Wrote: ../Figures/lat-nomad-availability-exp15.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']


filename=f"{location}lat-{orch}-{var_name}-{exp}.png"
display(Image(filename=filename, retina=True))
