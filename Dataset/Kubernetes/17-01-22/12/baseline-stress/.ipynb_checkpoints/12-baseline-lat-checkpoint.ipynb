# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/12/baseline-stress
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/12/baseline-stress/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/12/baseline-stress/../Figures'

# %%
# %env var=12,13,15
# %env var_name=baseline-stress
# %env exp=exp12

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=k8s

# !pwd
# !echo

# what to copy
# !cp ../$orch-$sn-* .
# !cp ../$orch-$mm-* .
# !cp ../$orch-$hr-* .

# !for file in $orch-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=12,13,15
# env: var_name=baseline-stress
# env: exp=exp12
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=k8s
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/12/baseline-stress
#
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R1000
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R10000
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R1500
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R2000
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R2500
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R3000
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R4000
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R500
# k8s-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R6000
# k8s-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R1000
# k8s-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R2000
# k8s-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R3000
# k8s-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R4000
# k8s-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R500
# k8s-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R5000
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R10000
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R1500
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R2000
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R3000
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R4000
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R500
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R5000
# k8s-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R6000

# %%
# print which params to include
# !for file in $orch-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in $orch-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in $orch-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# t4-c512-R10000
# t4-c512-R1500
# t4-c512-R2000
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R500
# t4-c512-R5000
# t4-c512-R6000
# t4-c512-R1000
# t4-c512-R2000
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R500
# t4-c512-R5000
# t4-c512-R1000
# t4-c512-R10000
# t4-c512-R1500
# t4-c512-R2000
# t4-c512-R2500
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R500
# t4-c512-R6000

# %%
# rename to param(s)
# !for file in $orch-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in $orch-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in $orch-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)$orch-$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$orch-$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$orch-$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/k8s-sn-baseline-stress-exp12.png
# Wrote: ../Figures/k8s-mm-baseline-stress-exp12.png
# Wrote: ../Figures/k8s-hr-baseline-stress-exp12.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

for bench in ['sn','mm','hr']:
    filename=f"{location}{orch}-{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
