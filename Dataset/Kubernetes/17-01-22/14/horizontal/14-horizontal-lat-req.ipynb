# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/14/horizontal
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/14/horizontal/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/14/horizontal/../Figures'

# %%
# !cp ../k8s-* .
# !hdr-plot --save k8s-*

# %%
# %env var=15
# %env var_name=horizontal
# %env exp=exp14

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=k8s

# !pwd
# !echo

# what to copy
# !cp ../k8s-$sn-* .
# !cp ../k8s-$mm-* .
# !cp ../k8s-$hr-* .

# !for file in k8s-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15
# env: var_name=horizontal
# env: exp=exp14
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=k8s
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/14/horizontal
#
# k8s-hr-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R100
# k8s-hr-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R1000
# k8s-hr-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R1500
# k8s-hr-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R200
# k8s-hr-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R2000
# k8s-hr-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R2500
# k8s-hr-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R500
# k8s-mm-wrk-compose-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R1000
# k8s-mm-wrk-compose-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R2000
# ...

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)latency-$orch-horizontal.png --nobox --lat_req k8s-* --legend_fontsize 20
# Out:
# Multiple benchmarks but one param
# Wrote: ../Figures/latency-k8s-horizontal.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

filename=f"{location}latency-{orch}-horizontal.png"
display(Image(filename=filename, retina=True))
