# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/Cluster1/14/horizontal
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/Cluster1/14/horizontal/../Figures

# %%
# %env var=15
# %env var_name=horizontal
# %env exp=exp14

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../k8s-$sn-* .
# !cp ../k8s-$mm-* .
# !cp ../k8s-$hr-* .

# !for file in k8s-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15
# env: var_name=horizontal
# env: exp=exp14
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/Cluster1/14/horizontal
#
# zsh:1: no matches found: ../k8s-mm-*
# zsh:1: no matches found: ../k8s-hr-*
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R10000
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R1500
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R2000
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R3000
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R4000
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R500
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R5000
# k8s-sn-wrk-mixed-c6525-25g-exp14-havail0-hori0-verti1-infi1-t4-c512-d30-R6000

# %%
# print which params to include
# !for file in k8s-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in k8s-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in k8s-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# R10000
# R1500
# R2000
# R3000
# R4000
# R500
# R5000
# R6000
# zsh:1: no matches found: k8s-mm-*
# zsh:1: no matches found: k8s-hr-*

# %%
# rename to param(s)
# !for file in k8s-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in k8s-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in k8s-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done
# Out:
# zsh:1: no matches found: k8s-mm-*
# zsh:1: no matches found: k8s-hr-*

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/sn-horizontal-exp14.png
# zsh:1: no matches found: mm-*
# zsh:1: no matches found: hr-*

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']

for bench in ['sn','mm','hr']:
    filename=f"{location}{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <module>
#       7 for bench in ['sn','mm','hr']:
#       8     filename=f"{location}{bench}-{var_name}-{exp}.png"
# ----> 9     display(Image(filename=filename, retina=True))
#
# File ~/Documents/Thesis/Results/Swarm/venv/lib/python3.9/site-packages/IPython/core/display.py:952, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     950 self.unconfined = unconfined
#     951 self.alt = alt
# --> 952 super(Image, self).__init__(data=data, url=url, filename=filename,
#     953         metadata=metadata)
#     955 if self.width is None and self.metadata.get('width', {}):
#     956     self.width = metadata['width']
#
# File ~/Documents/Thesis/Results/Swarm/venv/lib/python3.9/site-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
#     328 self._check_data()
#
# File ~/Documents/Thesis/Results/Swarm/venv/lib/python3.9/site-packages/IPython/core/display.py:987, in Image.reload(self)
#     985 """Reload the raw data from file or URL."""
#     986 if self.embed:
# --> 987     super(Image,self).reload()
#     988     if self.retina:
#     989         self._retina_shape()
#
# File ~/Documents/Thesis/Results/Swarm/venv/lib/python3.9/site-packages/IPython/core/display.py:352, in DisplayObject.reload(self)
#     350 """Reload the raw data from file or URL."""
#     351 if self.filename is not None:
# --> 352     with open(self.filename, self._read_flags) as f:
#     353         self.data = f.read()
#     354 elif self.url is not None:
#     355     # Deferred import
#
# FileNotFoundError: [Errno 2] No such file or directory: '../Figures/mm-horizontal-exp14.png'
