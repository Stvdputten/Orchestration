# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/10/duration-new-params
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/10/duration-new-params/../Figures

# %%
# !cp ../swarm-* .
# !hdr-plot --save swarm-*

# %%
# %env var=15,16
# %env var_name=duration-new-params
# %env exp=exp10

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15,16
# env: var_name=duration-new-params
# env: exp=exp10
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/10/duration-new-params
#
# swarm-hr-wrk-mixed-c6525-25g-exp10-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R14000
# swarm-hr-wrk-mixed-c6525-25g-exp10-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R16000
# swarm-mm-wrk-compose-c6525-25g-exp10-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R5000
# swarm-mm-wrk-compose-c6525-25g-exp10-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R6000
# swarm-sn-wrk-mixed-c6525-25g-exp10-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R2000
# swarm-sn-wrk-mixed-c6525-25g-exp10-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R3000

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# d150-R2000
# d150-R3000
# d150-R5000
# d150-R6000
# d150-R14000
# d150-R16000

# %%
# rename to param(s)
# !for file in swarm-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# %env var_name=breaking-point
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/sn-duration-new-params-exp10.png
# Wrote: ../Figures/mm-duration-new-params-exp10.png
# Wrote: ../Figures/hr-duration-new-params-exp10.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']

for bench in ['sn','mm','hr']:
    filename=f"{location}{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
