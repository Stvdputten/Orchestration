# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/4/duration
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/4/duration/../Figures

# %%
# %env var=15
# %env var_name=duration
# %env exp=exp4

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15
# env: var_name=duration
# env: exp=exp4
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/4/duration
#
# swarm-hr-wrk-mixed-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R500
# swarm-hr-wrk-mixed-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R500
# swarm-hr-wrk-mixed-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d60-R500
# swarm-mm-wrk-compose-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R500
# swarm-mm-wrk-compose-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R500
# swarm-mm-wrk-compose-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d60-R500
# swarm-sn-wrk-mixed-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d150-R500
# swarm-sn-wrk-mixed-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R500
# swarm-sn-wrk-mixed-c6525-25g-exp4-havail0-hori1-verti1-infi1-client1-t4-c512-d60-R500

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# d150
# d30
# d60
# d150
# d30
# d60
# d150
# d30
# d60

# %%
# rename to param(s)
# !for file in swarm-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-*
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-*
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-*
# Out:
# Wrote: ../Figures/sn-duration-exp4.png
# Wrote: ../Figures/mm-duration-exp4.png
# Wrote: ../Figures/hr-duration-exp4.png

# %%
from IPython import display
exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
display.Image(f"{location}sn-{var_name}-{exp}.png")

# %%
display.Image(f"{location}mm-{var_name}-{exp}.png")

# %%
display.Image(f"{location}hr-{var_name}-{exp}.png")
