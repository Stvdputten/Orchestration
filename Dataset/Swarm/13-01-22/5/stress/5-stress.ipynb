# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/5/stress
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/5/stress/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/5/stress/../Figures'

# %%
# %env var=13,14,16
# %env var_name=stress
# %env exp=exp5

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=13,14,16
# env: var_name=stress
# env: exp=exp5
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/5/stress
#
# swarm-hr-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2500
# swarm-hr-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-hr-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3500
# swarm-hr-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000
# swarm-hr-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R5000
# swarm-hr-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R6000
# swarm-mm-wrk-compose-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2500
# swarm-mm-wrk-compose-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-mm-wrk-compose-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3500
# swarm-mm-wrk-compose-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000
# swarm-mm-wrk-compose-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R5000
# swarm-mm-wrk-compose-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R6000
# swarm-sn-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2500
# swarm-sn-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-sn-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3500
# swarm-sn-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000
# swarm-sn-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R5000
# swarm-sn-wrk-mixed-c6525-25g-exp5-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R6000

# %%
# !cp ../swarm-* .
# !hdr-plot --save swarm-*

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# t4-c512-R2500
# t4-c512-R3000
# t4-c512-R3500
# t4-c512-R4000
# t4-c512-R5000
# t4-c512-R6000
# t4-c512-R2500
# t4-c512-R3000
# t4-c512-R3500
# t4-c512-R4000
# t4-c512-R5000
# t4-c512-R6000
# t4-c512-R2500
# t4-c512-R3000
# t4-c512-R3500
# t4-c512-R4000
# t4-c512-R5000
# t4-c512-R6000

# %%
# rename to param(s)
# !for file in swarm-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 16
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 16
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 16
# Out:
# Wrote: ../Figures/sn-stress-exp5.png
# Wrote: ../Figures/mm-stress-exp5.png
# Wrote: ../Figures/hr-stress-exp5.png

# %%
from IPython import display
exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
display.Image(f"{location}sn-{var_name}-{exp}.png")

# %%
display.Image(f"{location}mm-{var_name}-{exp}.png")

# %%
display.Image(f"{location}hr-{var_name}-{exp}.png")
