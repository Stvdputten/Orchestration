# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/9/redeployment
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/9/redeployment/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/9/redeployment/../Figures'

# %%
# !cp ../swarm-* .
# !hdr-plot --save swarm-*

# %%
# %env var=16
# %env var_name=redeployment
# %env exp=exp9

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=16
# env: var_name=redeployment
# env: exp=exp9
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/9/redeployment
#
# swarm-hr-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R12000
# swarm-hr-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R14000
# swarm-hr-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R16000
# swarm-hr-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R18000
# swarm-hr-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R20000
# swarm-mm-wrk-compose-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2500
# swarm-mm-wrk-compose-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-mm-wrk-compose-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000
# swarm-mm-wrk-compose-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R5000
# swarm-mm-wrk-compose-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R6000
# swarm-sn-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R1500
# swarm-sn-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-sn-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2500
# swarm-sn-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3500
# swarm-sn-wrk-mixed-c6525-25g-exp9-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# R1500
# R2000
# R2500
# R3500
# R4000
# R2500
# R3000
# R4000
# R5000
# R6000
# R12000
# R14000
# R16000
# R18000
# R20000

# %%
# rename to param(s)
# !for file in swarm-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# %env var_name=breaking-point
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-R* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-R* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-R* --legend_fontsize 20
# Out:
# Wrote: ../Figures/sn-redeployment-exp9.png
# Wrote: ../Figures/mm-redeployment-exp9.png
# Wrote: ../Figures/hr-redeployment-exp9.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']

for bench in ['sn','mm','hr']:
    filename=f"{location}{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
