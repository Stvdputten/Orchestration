# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/12/baseline-stress
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/12/baseline-stress/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/12/baseline-stress/../Figures'

# %%
# %env var=13,14,16
# %env var_name=baseline-stress
# %env exp=exp12

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=swarm

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=13,14,16
# env: var_name=baseline-stress
# env: exp=exp12
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=swarm
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/12/baseline-stress
#
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R1000
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R1500
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2500
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R500
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R1000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R500
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R1500
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R500

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# t4-c512-R1500
# t4-c512-R2000
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R500
# t4-c512-R1000
# t4-c512-R2000
# t4-c512-R3000
# t4-c512-R500
# t4-c512-R1000
# t4-c512-R1500
# t4-c512-R2000
# t4-c512-R2500
# t4-c512-R3000
# t4-c512-R500

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)lat-$orch-$var_name-$exp.png --nobox --lat_req swarm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)lat-$orch-$mm-$var_name-$exp.png --nobox --lat_req $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)lat-$orch-$hr-$var_name-$exp.png --nobox --lat_req $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/lat-swarm-baseline-stress-exp12.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

filename=f"{location}lat-{orch}-{var_name}-{exp}.png"
display(Image(filename=filename, retina=True))
