# %%
# !rm df-*-checkpoint.csv
# Out:
# zsh:1: no matches found: df-*-checkpoint.csv

# %%
import os
import glob

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load all datasets

# %%
all_files = glob.glob("*.csv")
df = pd.concat((pd.read_csv(f) for f in all_files))
df = df.drop_duplicates()
print(df.shape)
# Out:
# (263, 20)

# %%
df['Orchestrator'] = df['Orchestrator'].astype('category')
df['Benchmark'] = df['Benchmark'].astype('category')
df['Exp'] = df['Exp'].astype('category')
# df['Latency'] = df['Latency']
df['Requests'] = df['Requests'].astype(int)

# %%
df_0 = df.loc[df['Exp'] == 'exp0']
df_1 = df.loc[df['Exp'] == 'exp1']
df_2 = df.loc[df['Exp'] == 'exp2']
df_3 = df.loc[df['Exp'] == 'exp3']
df_4 = df.loc[df['Exp'] == 'exp4']
df_5 = df.loc[df['Exp'] == 'exp5']
df_6 = df.loc[df['Exp'] == 'exp6']
df_7 = df.loc[df['Exp'] == 'exp7']
df_8 = df.loc[df['Exp'] == 'exp8']
df_9 = df.loc[df['Exp'] == 'exp9']
df_10 = df.loc[df['Exp'] == 'exp10']
df_11 = df.loc[df['Exp'] == 'exp11']

# %%
# Global settings
fontsize = 20
legend_location = "lower right"

# %% [markdown]
# # Exp8 Temporal

# %%
# Define the allowed values
allowed_values = [500, 1000, 2000, 3000, 4000, 6000, 10000, 15000]

# Filter the DataFrame
df_8 = df_8[df_8['Requests'].isin(allowed_values)]
print("\nFiltered DataFrame:")
# Out:
# Filtered DataFrame:

# %%
df_8.iloc[:,[0,1,2,5,6,10,11,12,-1]].head()
# Out:
#    Latency  Requests  Throughput Orchestrator Benchmark  Availability  \
# 0     3.77       500     14815.0        swarm        mm             0
# 1     8.06       500     14922.0        swarm        sn             0
# 2     8.03       500     14921.0        swarm        sn             0
# 3     7.07       500     14924.0        swarm        sn             0
# 4     4.78       500     14921.0        swarm        mm             0
#
#    Horizontal  Vertical  ReqSec
# 0           1         1  493.45
# 1           1         1  497.27
# 2           1         1  497.31
# 3           1         1  497.35
# 4           1         1  497.28

# %%
df_8.shape
# Out:
# (59, 20)

# %%
labels = df_8['Benchmark'].unique()

# %%
df_8
# Out:
#      Latency  Requests  Throughput  Measured_Throughput  Baseline  \
# 0       3.77       500     14815.0                 9900         0
# 1       8.06       500     14922.0                 9877         0
# 2       8.03       500     14921.0                 9876         0
# 3       7.07       500     14924.0                 9879         0
# 4       4.78       500     14921.0                 9876         0
# 5       5.89       500     14815.0                 9899         0
# 6       5.45       500     14924.0                 9878         0
# 7       4.29       500     14815.0                 9899         0
# 8       7.70      1000     29631.0                19872         0
# 9       7.59      1000     29633.0                19874         0
# 10      6.16      1000     29632.0                19873         0
# 11      5.60      1000     29630.0                19871         0
# 12      5.11      1000     29635.0                19876         0
# 13      4.08      1000     29902.0                19931         0
# 14      4.92      1000     29636.0                19876         0
# 15      4.88      1000     29633.0                19874         0
# 16      8.84      2000     58709.0                39651         0
# 17      8.64      2000     59635.0                39732         0
# 18      5.57      2000     59647.0                39732         0
# 19      6.97      2000     59181.0                39685         0
# 20      8.49      2000     59180.0                39684         0
# 21      6.51      2000     58712.0                39646         0
# 22      5.25      2000     59648.0                39736         0
# 23      4.92      2000     59195.0                39694         0
# 24     10.22      3000     89117.0                59704         0
# 25     10.01      3000     89116.0                59703         0
# 26      7.59      3000     89122.0                59699         0
# 27      5.50      3000     89127.0                59704         0
# 28      8.03      3000     89116.0                59704         0
# 29     14.75      3000     88412.0                59720         0
# 30     10.56      3000     89798.0                59637         0
# 31   8040.00      4000     95079.0                61200         0
# 32     12.79      4000    118927.0                79812         0
# 33      5.88      4000    118950.0                79822         0
# 34     12.92      4000    118932.0                79823         0
# 35      8.91      4000    118942.0                79817         0
# 36     37.69      4000    118009.0                79850         0
# 37     70.08      4000    118909.0                79840         0
# 38     14.78      6000    178518.0               119809         0
# 39     25.20      6000    179959.0               119837         0
# 40     23.23      6000    178506.0               119796         0
# 41  14220.00      6000     98765.0                64448         0
# 42      7.57      6000    179991.0               119829         0
# 43   9670.00      6000    131991.0                87749         0
# 44  10750.00      6000    122717.0                81414         0
# 45   9670.00     10000    268303.0               178269         0
# 46  17270.00     10000    129982.0                86360         0
# 47     47.36     10000    295267.0               199277         0
# 48  10450.00     10000    262808.0               175267         0
# 49  18320.00     10000    119077.0                78439         0
# 50   4830.00     10000    284252.0               188519         0
# 51  19870.00     10000    100396.0                64448         0
# 52  21360.00     15000    129102.0                86283         0
# 53  22300.00     15000    110591.0                72286         0
# 54  23460.00     15000     99262.0                64831         0
# 55    298.24     15000    442424.0               298943         0
# 56  15560.00     15000    261133.0               173716         0
# 57  16090.00     15000    267122.0               176307         0
# 58  17710.00     15000    260701.0               172812         0
#
#    Orchestrator Benchmark  Infinite   Exp  N  Availability  Horizontal  \
# 0         swarm        mm         0  exp8  1             0           1
# 1         swarm        sn         0  exp8  3             0           1
# 2         swarm        sn         0  exp8  2             0           1
# 3         swarm        sn         0  exp8  1             0           1
# 4         swarm        mm         0  exp8  3             0           1
# 5         swarm        hr         0  exp8  1             0           1
# 6         swarm        hr         0  exp8  2             0           1
# 7         swarm        mm         0  exp8  2             0           1
# 8         swarm        sn         0  exp8  3             0           1
# 9         swarm        sn         0  exp8  2             0           1
# 10        swarm        sn         0  exp8  1             0           1
# 11        swarm        mm         0  exp8  3             0           1
# 12        swarm        hr         0  exp8  1             0           1
# 13        swarm        mm         0  exp8  1             0           1
# 14        swarm        hr         0  exp8  2             0           1
# 15        swarm        mm         0  exp8  2             0           1
# 16        swarm        sn         0  exp8  3             0           1
# 17        swarm        sn         0  exp8  2             0           1
# 18        swarm        mm         0  exp8  1             0           1
# 19        swarm        mm         0  exp8  2             0           1
# 20        swarm        mm         0  exp8  3             0           1
# 21        swarm        sn         0  exp8  1             0           1
# 22        swarm        hr         0  exp8  1             0           1
# 23        swarm        hr         0  exp8  2             0           1
# 24        swarm        sn         0  exp8  3             0           1
# 25        swarm        sn         0  exp8  2             0           1
# 26        swarm        sn         0  exp8  1             0           1
# 27        swarm        hr         0  exp8  1             0           1
# 28        swarm        mm         0  exp8  1             0           1
# 29        swarm        mm         0  exp8  3             0           1
# 30        swarm        mm         0  exp8  2             0           1
# 31        swarm        mm         0  exp8  3             0           1
# 32        swarm        sn         0  exp8  3             0           1
# 33        swarm        hr         0  exp8  1             0           1
# 34        swarm        sn         0  exp8  2             0           1
# 35        swarm        sn         0  exp8  1             0           1
# 36        swarm        mm         0  exp8  1             0           1
# 37        swarm        mm         0  exp8  2             0           1
# 38        swarm        sn         0  exp8  1             0           1
# 39        swarm        sn         0  exp8  3             0           1
# 40        swarm        sn         0  exp8  2             0           1
# 41        swarm        mm         0  exp8  3             0           1
# 42        swarm        hr         0  exp8  1             0           1
# 43        swarm        mm         0  exp8  1             0           1
# 44        swarm        mm         0  exp8  2             0           1
# 45        swarm        sn         0  exp8  3             0           1
# 46        swarm        mm         0  exp8  1             0           1
# 47        swarm        hr         0  exp8  1             0           1
# 48        swarm        sn         0  exp8  2             0           1
# 49        swarm        mm         0  exp8  2             0           1
# 50        swarm        sn         0  exp8  1             0           1
# 51        swarm        mm         0  exp8  3             0           1
# 52        swarm        mm         0  exp8  1             0           1
# 53        swarm        mm         0  exp8  2             0           1
# 54        swarm        mm         0  exp8  3             0           1
# 55        swarm        hr         0  exp8  1             0           1
# 56        swarm        sn         0  exp8  2             0           1
# 57        swarm        sn         0  exp8  1             0           1
# 58        swarm        sn         0  exp8  3             0           1
#
#     Vertical  Threads  Connections  Duration       Mean        Max    StdDev  \
# 0          1        4          512        30      2.967      8.320     0.286
# 1          1        4          512        30      5.020     13.064     1.162
# 2          1        4          512        30      5.029     13.536     1.162
# 3          1        4          512        30      2.588     27.504     1.728
# 4          1        4          512        30      3.834     10.016     0.335
# 5          1        4          512        30      2.138     25.248     1.414
# 6          1        4          512        30      2.100      7.176     1.190
# 7          1        4          512        30      3.398      8.496     0.302
# 8          1        4          512        30      4.574     11.720     1.090
# 9          1        4          512        30      4.576     18.624     1.091
# 10         1        4          512        30      2.887     10.520     1.602
# 11         1        4          512        30      4.171      9.192     0.453
# 12         1        4          512        30      1.827     24.544     1.265
# 13         1        4          512        30      3.022      9.712     0.336
# 14         1        4          512        30      1.788     15.064     1.027
# 15         1        4          512        30      3.625     14.456     0.405
# 16         1        4          512        30      4.665     36.704     1.454
# 17         1        4          512        30      4.643     17.120     1.329
# 18         1        4          512        30      3.516     15.848     0.603
# 19         1        4          512        30      4.253     19.792     0.732
# 20         1        4          512        30      5.121     16.160     0.889
# 21         1        4          512        30      3.007     13.400     1.547
# 22         1        4          512        30      1.802     25.696     1.204
# 23         1        4          512        30      1.766     16.704     1.028
# 24         1        4          512        30      5.009     20.992     1.640
# 25         1        4          512        30      4.945     19.632     1.604
# 26         1        4          512        30      3.360     14.384     1.636
# 27         1        4          512        30      1.905     28.112     1.319
# 28         1        4          512        30      4.327     35.136     1.008
# 29         1        4          512        30      7.023     32.112     2.048
# 30         1        4          512        30      5.456     20.960     1.356
# 31         1        4          512        30   3712.736  11034.624  1735.257
# 32         1        4          512        30      5.652     26.944     2.130
# 33         1        4          512        30      2.054     78.208     1.868
# 34         1        4          512        30      5.636     38.080     2.172
# 35         1        4          512        30      3.807     21.120     1.815
# 36         1        4          512        30      8.054    362.752    11.646
# 37         1        4          512        30     13.957    200.960    13.127
# 38         1        4          512        30      5.355     44.128     2.818
# 39         1        4          512        30      8.072     83.264     4.603
# 40         1        4          512        30      7.809     90.368     4.253
# 41         1        4          512        30   8323.467  16326.656  2674.443
# 42         1        4          512        30      2.643    144.128     4.743
# 43         1        4          512        30   5235.788  12468.224  1908.826
# 44         1        4          512        30   6055.239  12967.936  2118.057
# 45         1        4          512        30   1808.027  13279.232  2308.210
# 46         1        4          512        30  11059.938  18726.912  3332.593
# 47         1        4          512        30      4.818    247.168    10.236
# 48         1        4          512        30   1916.608  14942.208  2364.605
# 49         1        4          512        30  11694.542  19922.944  3581.788
# 50         1        4          512        30    623.820   6983.680  1085.638
# 51         1        4          512        30  12688.606  21397.504  3702.912
# 52         1        4          512        30  14032.529  22560.768  4112.233
# 53         1        4          512        30  14590.819  23576.576  4430.054
# 54         1        4          512        30  15812.518  24641.536  4607.348
# 55         1        4          512        30     30.015    646.656    55.974
# 56         1        4          512        30   7969.064  20021.248  3083.586
# 57         1        4          512        30   7451.328  21004.288  3424.302
# 58         1        4          512        30   7496.610  21430.272  3806.082
#
#       ReqSec
# 0     493.45
# 1     497.27
# 2     497.31
# 3     497.35
# 4     497.28
# 5     493.62
# 6     497.37
# 7     493.59
# 8     987.64
# 9     987.67
# 10    987.56
# 11    987.56
# 12    987.75
# 13    996.63
# 14    987.66
# 15    987.73
# 16   1956.92
# 17   1987.58
# 18   1988.10
# 19   1972.70
# 20   1972.74
# 21   1956.96
# 22   1988.09
# 23   1972.83
# 24   2970.47
# 25   2970.27
# 26   2970.61
# 27   2970.73
# 28   2970.55
# 29   2947.17
# 30   2993.40
# 31   3169.09
# 32   3963.96
# 33   3964.92
# 34   3964.41
# 35   3964.60
# 36   3933.81
# 37   3963.32
# 38   5950.65
# 39   5998.74
# 40   5950.27
# 41   3292.28
# 42   5999.79
# 43   4399.92
# 44   4090.75
# 45   8943.60
# 46   4332.89
# 47   9842.37
# 48   8760.33
# 49   3969.06
# 50   9475.02
# 51   3343.45
# 52   4303.60
# 53   3686.54
# 54   3308.66
# 55  14747.79
# 56   8704.51
# 57   8904.06
# 58   8690.16

# %%
fig, ax = plt.subplots(figsize=(8,8))
labels = ["sn", "mm", "hr"]

p = sns.lineplot(x="Requests", y="Latency", data=df_8, hue="Benchmark", style='Benchmark', linewidth=3)

# %%
# Exp5
fig, ax = plt.subplots(3, 1, figsize=(16,8))
xticks = df_7['Requests'].unique()

plt.subplot(311)
p = sns.lineplot(x="Requests", y="Latency", data=df_5, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
p.axes.xaxis.set_visible(False)
# p.axes.yaxis.set_visible(False)
plt.ylabel("")
p.set_xticks(xticks)

# plt.ylabel('Latency (milliseconds)', fontsize=12)


# Exp7
plt.subplot(312)
p = sns.lineplot(x="Requests", y="Latency", data=df_7, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
plt.ylabel('Latency (milliseconds)', fontsize=15)
p.axes.xaxis.set_visible(False)


# Exp8
plt.subplot(313)
p = sns.lineplot(x="Requests", y="Latency", data=df_8, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
p.set_xticks(xticks)
# plt.ylabel('Latency (milliseconds)', fontsize=12)
plt.ylabel("")

plt.xticks(rotation = 45, fontsize=12)
plt.xlabel('Requests', fontsize=15)

# plt.ylabel()

plt.legend(labels, fontsize=15)
plt.savefig("Figures/exp8-exp7-exp5.png", bbox_inches='tight')

# %%
# Exp5
fig, ax = plt.subplots(figsize=(16,8))

# Exp8
# plt.subplot(213)
p = sns.lineplot(x="Requests", y="Latency", data=df_8, hue="Benchmark", style='Benchmark', linewidth=3)
p.set_xticks(xticks)
plt.xticks(rotation = 45, fontsize=10)
plt.ylabel('Latency (milliseconds)', fontsize=12)
plt.xlabel('Requests', fontsize=15)
plt.legend(labels, fontsize=15)
plt.savefig("Figures/exp8.png", bbox_inches='tight')
