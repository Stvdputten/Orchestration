# %%
# !rm df-*-checkpoint.csv
# Out:
# zsh:1: no matches found: df-*-checkpoint.csv

# %%
import os
import glob

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load all datasets

# %%
all_files = glob.glob("*.csv")
df = pd.concat((pd.read_csv(f) for f in all_files))
df = df.drop_duplicates()
print(df.shape)
# Out:
# (555, 18)

# %%
df['Orchestrator'] = df['Orchestrator'].astype('category')
df['Benchmark'] = df['Benchmark'].astype('category')
df['Exp'] = df['Exp'].astype('category')
# df['Latency'] = df['Latency']
df['Requests'] = df['Requests'].astype(int)

# %%
df_0 = df.loc[df['Exp'] == 'exp0']
df_1 = df.loc[df['Exp'] == 'exp1']
df_2 = df.loc[df['Exp'] == 'exp2']
df_3 = df.loc[df['Exp'] == 'exp3']
df_4 = df.loc[df['Exp'] == 'exp4']
df_5 = df.loc[df['Exp'] == 'exp5']
df_6 = df.loc[df['Exp'] == 'exp6']
df_7 = df.loc[df['Exp'] == 'exp7']
df_8 = df.loc[df['Exp'] == 'exp8']
df_9 = df.loc[df['Exp'] == 'exp9']
df_10 = df.loc[df['Exp'] == 'exp10']
df_11 = df.loc[df['Exp'] == 'exp11']

# %%
# Global settings
fontsize = 20
legend_location = "lower right"

# %% [markdown]
# # Exp8 Temporal

# %%
df_8.iloc[:,[0,1,2,5,6,10,11,12,-1]].head()
# Out:
#     Latency  Requests  Throughput Benchmark  Infinite  Vertical  Threads  \
# 0      5.96      1500     44333.0        sn         1         1        4
# 1      6.42      2000     59185.0        sn         1         1        4
# 2      6.40      2500     74372.0        mm         1         1        4
# 3  20920.00      2500     40150.0        sn         1         1        4
# 4     10.71      3000     89116.0        mm         1         1        4
#
#    Connections   ReqSec
# 0          512  1477.54
# 1          512  1972.70
# 2          512  2479.03
# 3          512  1337.95
# 4          512  2970.50

# %%
df_8.shape
# Out:
# (15, 18)

# %%
labels = df_8['Benchmark'].unique()

# %%
df_8
# Out:
#      Latency  Requests  Throughput  Baseline Orchestrator Benchmark  Infinite  \
# 0       5.96      1500     44333.0         0        swarm        sn         1
# 1       6.42      2000     59185.0         0        swarm        sn         1
# 2       6.40      2500     74372.0         0        swarm        mm         1
# 3   20920.00      2500     40150.0         0        swarm        sn         1
# 4      10.71      3000     89116.0         0        swarm        mm         1
# 5   21150.00      3000     37847.0         0        swarm        sn         1
# 6      12.39      4000    118932.0         0        swarm        mm         1
# 7   22860.00      4000     37825.0         0        swarm        sn         1
# 8      19.42      5000    149798.0         0        swarm        mm         1
# 9    3870.00      6000    166813.0         0        swarm        mm         1
# 10     98.37     12000    357381.0         0        swarm        hr         1
# 11    722.94     14000    415611.0         0        swarm        hr         1
# 12   2770.00     16000    452004.0         0        swarm        hr         1
# 13   5690.00     18000    460284.0         0        swarm        hr         1
# 14   7350.00     20000    465620.0         0        swarm        hr         1
#
#      Exp  Availability  Horizontal  Vertical  Threads  Connections  Duration  \
# 0   exp8             0           1         1        4          512        30
# 1   exp8             0           1         1        4          512        30
# 2   exp8             0           1         1        4          512        30
# 3   exp8             0           1         1        4          512        30
# 4   exp8             0           1         1        4          512        30
# 5   exp8             0           1         1        4          512        30
# 6   exp8             0           1         1        4          512        30
# 7   exp8             0           1         1        4          512        30
# 8   exp8             0           1         1        4          512        30
# 9   exp8             0           1         1        4          512        30
# 10  exp8             0           1         1        4          512        30
# 11  exp8             0           1         1        4          512        30
# 12  exp8             0           1         1        4          512        30
# 13  exp8             0           1         1        4          512        30
# 14  exp8             0           1         1        4          512        30
#
#         Mean        Max    StdDev    ReqSec
# 0      2.544      9.344     1.571   1477.54
# 1      2.955     10.840     1.499   1972.70
# 2      3.243     35.584     0.932   2479.03
# 3   7209.392  25460.736  5342.395   1337.95
# 4      3.615     29.824     1.410   2970.50
# 5   8541.581  23560.192  5592.401   1261.47
# 6      4.313     43.072     1.774   3964.46
# 7   9383.162  24363.008  5874.487   1257.54
# 8      6.427     67.648     3.265   4993.38
# 9   1291.743   5160.960   881.809   5560.51
# 10    19.151    351.744    18.799  11912.98
# 11   130.283   1428.480   141.472  13852.63
# 12   945.739   3899.392   628.472  15067.19
# 13  2978.257   6860.800  1100.670  15343.02
# 14  4338.213   8650.752  1391.049  15520.95

# %%
fig, ax = plt.subplots(figsize=(8,8))
labels = ["sn", "mm", "hr"]

p = sns.lineplot(x="Requests", y="Latency", data=df_8, hue="Benchmark", style='Benchmark', linewidth=3)

# %%
# Exp5
fig, ax = plt.subplots(3, 1, figsize=(16,8))
xticks = df_7['Requests'].unique()

plt.subplot(311)
p = sns.lineplot(x="Requests", y="Latency", data=df_5, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
p.axes.xaxis.set_visible(False)
# p.axes.yaxis.set_visible(False)
plt.ylabel("")
p.set_xticks(xticks)

# plt.ylabel('Latency (milliseconds)', fontsize=12)


# Exp7
plt.subplot(312)
p = sns.lineplot(x="Requests", y="Latency", data=df_7, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
plt.ylabel('Latency (milliseconds)', fontsize=15)
p.axes.xaxis.set_visible(False)


# Exp8
plt.subplot(313)
p = sns.lineplot(x="Requests", y="Latency", data=df_8, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
p.set_xticks(xticks)
# plt.ylabel('Latency (milliseconds)', fontsize=12)
plt.ylabel("")

plt.xticks(rotation = 45, fontsize=10)
plt.xlabel('Requests', fontsize=15)

# plt.ylabel()

plt.legend(labels, fontsize=15)
plt.savefig("Figures/exp8-exp7-exp5.png", bbox_inches='tight')

# %%
# Exp5
fig, ax = plt.subplots(3, 1, figsize=(16,8))
xticks = df_7['Requests'].unique()

plt.subplot(211)
p = sns.lineplot(x="Requests", y="Latency", data=df_5, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
p.axes.xaxis.set_visible(False)
p.set_xticks(xticks)
plt.ylabel('Latency (milliseconds)', fontsize=12)

# Exp7
plt.subplot(212)
p = sns.lineplot(x="Requests", y="Latency", data=df_7, hue="Benchmark", style='Benchmark', linewidth=3)
p.set_xticks(xticks)
plt.xticks(rotation = 45, fontsize=10)
plt.ylabel('Latency (milliseconds)', fontsize=12)
plt.xlabel('Requests', fontsize=15)

# Exp8
plt.subplot(213)
p = sns.lineplot(x="Requests", y="Latency", data=df_8, hue="Benchmark", style='Benchmark', linewidth=3)
p.set_xticks(xticks)
plt.xticks(rotation = 45, fontsize=10)
plt.ylabel('Latency (milliseconds)', fontsize=12)
plt.xlabel('Requests', fontsize=15)



plt.legend(labels, fontsize=15)
plt.savefig("Figures/exp7-vs-exp5.png", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [12], in <module>
#      17 plt.xlabel('Requests', fontsize=15)
#      19 # Exp8
# ---> 20 plt.subplot(213)
#      21 p = sns.lineplot(x="Requests", y="Latency", data=df_8, hue="Benchmark", style='Benchmark', linewidth=3)
#      22 p.set_xticks(xticks)
#
# File ~/Documents/Thesis/Results/Swarm/venv/lib/python3.9/site-packages/matplotlib/pyplot.py:1268, in subplot(*args, **kwargs)
#    1265 fig = gcf()
#    1267 # First, search for an existing subplot with a matching spec.
# -> 1268 key = SubplotSpec._from_subplot_args(fig, args)
#    1270 for ax in fig.axes:
#    1271     # if we found an axes at the position sort out if we can re-use it
#    1272     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1273         # if the user passed no kwargs, re-use
#
# File ~/Documents/Thesis/Results/Swarm/venv/lib/python3.9/site-packages/matplotlib/gridspec.py:608, in SubplotSpec._from_subplot_args(figure, args)
#     606 else:
#     607     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 608         raise ValueError(
#     609             f"num must be 1 <= num <= {rows*cols}, not {num!r}")
#     610     i = j = num
#     611 return gs[i-1:j]
#
# ValueError: num must be 1 <= num <= 2, not 3

# %%
p = sns.catplot(x="Benchmark", y="Latency",data=df_7, order=["sn","mm","hr"])

# %%
# Exp5
fig, ax = plt.subplots(2, 1, figsize=(16,8))
xticks = df_7['Requests'].unique()

plt.subplot(211)
p = sns.lineplot(x="Requests", y="Latency", data=df_5, hue="Benchmark", style='Benchmark', linewidth=3, legend="")
p.axes.xaxis.set_visible(False)
p.set_xticks(xticks)

plt.ylabel('Latency (milliseconds)', fontsize=12)


plt.subplot(212)
p = sns.lineplot(x="Requests", y="Latency", data=df_7, hue="Benchmark", style='Benchmark', linewidth=3)
p.set_xticks(xticks)
plt.xticks(rotation = 45, fontsize=10)
plt.ylabel('Latency (milliseconds)', fontsize=12)
plt.xlabel('Requests', fontsize=15)


plt.legend(labels, fontsize=15)
plt.savefig("Figures/exp7-vs-exp5.png", bbox_inches='tight')

# %%
# exp 7
fig, ax = plt.subplots(figsize=(16,8))

p = sns.lineplot(x="Requests", y="Latency", data=df_7, hue="Benchmark", style="Benchmark", linewidth=3)
xticks = df_7['Requests'].unique()
p.legend(fontsize=15)
p.set_xlabel('Requests', fontsize=15)
p.set_ylabel('Latency (milliseconds)', fontsize=15)
p.set_xticks(xticks)
plt.xticks(rotation = 45, fontsize=10)
plt.xlim(0)
plt.savefig("Figures/exp7-expanded.png", bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=(16,8))
# plt.figure(1)
labels = ["sn", "mm", "hr"]

# p = sns.catplot(x="Requests", y="Latency", data=df_6, hue="Benchmark")
p = sns.pointplot(x="Requests", y="Latency", col="Benchmark", data=df_7, hue="Benchmark", style="Benchmark")

p.legend(loc="upper right", fontsize=20)
p.set_xlabel('Requests', fontsize=15)
p.set_ylabel('Latency (milliseconds)', fontsize=15)
# p.axes.get_xticks()
# xticks = [int(tick) for tick in p.axes[0][0].get_xticks()]
# plt.yticks(fontsize=15)
# plt.xticks(xticks, fontsize=15)
# plt.xlim(
# plt.savefig("Figures/exp7.png", bbox_inches='tight')
# Out:
# Text(0, 0.5, 'Latency (milliseconds)')

# %%
p = sns.lineplot(x="Requests", y="Latency", data=df_7, hue="Benchmark", style='Benchmark', linewidth=3)
