# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/all_params/all
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/all_params/all/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/all_params/all/../Figures'

# %%
# %env var=13,14,16
# %env var_name=baseline-stress

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=swarm

# !pwd
# !echo

# what to copy
# !cp ../$sn/swarm-$sn-* .
# !cp ../$mm/swarm-$mm-* .
# !cp ../$hr/swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=13,14,16
# env: var_name=baseline-stress
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=swarm
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/all_params/all

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)latency-$orch-$sn.png --nobox --lat_req swarm-sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)latency-$orch-$mm.png --nobox --lat_req swarm-mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)latency-$orch-$hr.png --nobox --lat_req swarm-hr-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)lat-$orch-$mm-$var_name-$exp.png --nobox --lat_req $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)lat-$orch-$hr-$var_name-$exp.png --nobox --lat_req $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/latency-sn.png
# Wrote: ../Figures/latency-mm.png
# Wrote: ../Figures/latency-hr.png

# %%
from IPython.display import display, Image

# exp=os.environ['exp']
# var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

# filename=f"{location}all-lat-{orch}-{var_name}-{exp}.png"
filename=f"{location}latency-{orch}-sn.png"
display(Image(filename=filename, retina=True))

# %%
filename=f"{location}latency-{orch}-mm.png"
display(Image(filename=filename, retina=True))

# %%
filename=f"{location}latency-{orch}-hr.png"
display(Image(filename=filename, retina=True))
