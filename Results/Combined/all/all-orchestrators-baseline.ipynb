# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Combined/all
# /Users/stvdputten/Documents/Thesis/Results/Combined/all/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Combined/all/../Figures'

# %%
# %env var=13,14,16
# %env var_name=baseline-stress

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=all

# !pwd
# !echo

# what to copy
# !cp ../13/*-$sn-* .
# !cp ../$mm/swarm-$mm-* .
# !cp ../$hr/swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=13,14,16
# env: var_name=baseline-stress
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=all
# /Users/stvdputten/Documents/Thesis/Results/Combined/all

# %%
# !rm *-sn-*
# !cp ../12/*-$sn-* .
# !hdr-plot --output $(echo $location)latency-$orch-$sn-baseline.png --nobox --legend_location "upper right" --lat_req_all *-sn-* --legend_fontsize 20
# !rm *-sn-*
# Out:
# zsh:1: no matches found: *-sn-*
# Multiple orchestrators one benchmark and one param
# baseline
# baseline
# baseline
# Wrote: ../Figures/latency-all-sn-baseline.png

# %%
# Overview of all
# %env var_name=t16-c512
# !rm *-sn-*
# !cp ../13/*-$sn-* .
# !hdr-plot --output $(echo $location)latency-$orch-$sn-vertical.png --legend_location "upper right" --nobox --lat_req_all *-sn-* --legend_fontsize 20
# !rm *-sn-*

# !hdr-plot --output $(echo $location)latency-$orch-$mm.png --nobox --lat_req swarm-mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)latency-$orch-$hr.png --nobox --lat_req swarm-hr-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)lat-$orch-$mm-$var_name-$exp.png --nobox --lat_req $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)lat-$orch-$hr-$var_name-$exp.png --nobox --lat_req $hr-* --legend_fontsize 20
# Out:
# zsh:1: no matches found: *-sn-*
# Multiple orchestrators one benchmark and one param
# vertical
# vertical
# vertical
# Wrote: ../Figures/latency-all-sn-vertical.png

# %%
# !rm *-sn-*
# !cp ../14/*-$sn-* .
# !hdr-plot --output $(echo $location)latency-$orch-$sn-horizontal.png --legend_location "upper right" --nobox --lat_req_all *-sn-* --legend_fontsize 20
# !rm *-sn-*
# Out:
# zsh:1: no matches found: *-sn-*
# Multiple orchestrators one benchmark and one param
# horizontal
# horizontal
# horizontal
# Wrote: ../Figures/latency-all-sn-horizontal.png

# %%
# !rm *-sn-*
# !cp ../15/*-$sn-* .
# !hdr-plot --output $(echo $location)latency-$orch-$sn-availability.png --legend_location "upper right" --nobox --lat_req_all *-sn-* --legend_fontsize 20
# !rm *-sn-*
# Out:
# Multiple orchestrators one benchmark and one param
# availability
# availability
# availability
# Wrote: ../Figures/latency-all-sn-availability.png

# %%
from IPython.display import display, Image

# exp=os.environ['exp']
# var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

# filename=f"{location}all-lat-{orch}-{var_name}-{exp}.png"
filename=f"{location}latency-{orch}-sn-baseline.png"
display(Image(filename=filename, retina=True))

# %%
filename=f"{location}latency-{orch}-sn-vertical.png"
display(Image(filename=filename, retina=True))

# %%
filename=f"{location}latency-{orch}-sn-horizontal.png"
display(Image(filename=filename, retina=True))

# %%
filename=f"{location}latency-{orch}-sn-availability.png"
display(Image(filename=filename, retina=True))
