# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/12/baseline-stress
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/12/baseline-stress/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/12/baseline-stress/../Figures'

# %%
# %env var=12,13,15
# %env var_name=baseline-stress
# %env exp=exp12

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=nomad

# !pwd
# !echo

# what to copy
# !cp ../$orch-$sn-* .
# !cp ../$orch-$mm-* .
# !cp ../$orch-$hr-* .

# !for file in nomad-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=12,13,15
# env: var_name=baseline-stress
# env: exp=exp12
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=nomad
# /Users/stvdputten/Documents/Thesis/Results/Hashi/14-01-22/12/baseline-stress
#
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R10000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R12000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R14000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R16000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R18000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R2000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R20000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R3000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R4000
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R500
# nomad-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R6000
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R3000
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R4000
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R500
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R5000
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R6000
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R7000
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d60-R500
# nomad-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d60-R7000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R10000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R1500
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R15000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R2000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R20000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R3000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R4000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R500
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d30-R5000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d60-R10000
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d60-R1500
# nomad-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-t4-c512-d60-R500

# %%
# print which params to include
# !for file in $orch-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in $orch-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in $orch-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# t4-c512-R10000
# t4-c512-R1500
# t4-c512-R15000
# t4-c512-R2000
# t4-c512-R20000
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R500
# t4-c512-R5000
# t4-c512-R10000
# t4-c512-R1500
# t4-c512-R500
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R500
# t4-c512-R5000
# t4-c512-R6000
# t4-c512-R7000
# t4-c512-R500
# t4-c512-R7000
# t4-c512-R10000
# t4-c512-R12000
# t4-c512-R14000
# t4-c512-R16000
# t4-c512-R18000
# t4-c512-R2000
# t4-c512-R20000
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R500
# t4-c512-R6000

# %%
# rename to param(s)
# !for file in $orch-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in $orch-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in $orch-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/sn-baseline-stress-exp12.png
# Wrote: ../Figures/mm-baseline-stress-exp12.png
# Wrote: ../Figures/hr-baseline-stress-exp12.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']

for bench in ['sn','mm','hr']:
    filename=f"{location}{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
