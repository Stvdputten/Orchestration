# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Hashi/all/all
# /Users/stvdputten/Documents/Thesis/Results/Hashi/all/all/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Hashi/all/all/../Figures'

# %%
# %env var=12,13,15
# %env var_name=baseline-stress
# %env exp=exp12

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=nomad

# !pwd
# !echo

# what to copy
# !cp ../sn/$orch-$sn-* .
# !cp ../mm/$orch-$mm-* .
# !cp ../hr/$orch-$hr-* .

# !for file in nomad-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=12,13,15
# env: var_name=baseline-stress
# env: exp=exp12
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=nomad
# /Users/stvdputten/Documents/Thesis/Results/Hashi/all/all

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)latency-$orch-$sn.png --legend_location "upper left" --nobox --lat_req $orch-sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)latency-$orch-$mm.png --legend_location "upper left" --nobox --lat_req $orch-mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)latency-$orch-$hr.png --legend_location "upper left" --nobox --lat_req $orch-hr-* --legend_fontsize 20
# Out:
# one benchmark but multiple params
# Wrote: ../Figures/latency-nomad-sn.png
# one benchmark but multiple params
# Wrote: ../Figures/latency-nomad-mm.png
# one benchmark but multiple params
# Wrote: ../Figures/latency-nomad-hr.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

filename=f"{location}latency-{orch}-sn.png"
display(Image(filename=filename, retina=True))

# %%
filename=f"{location}latency-{orch}-mm.png"
display(Image(filename=filename, retina=True))

# %%
filename=f"{location}latency-{orch}-hr.png"
display(Image(filename=filename, retina=True))
