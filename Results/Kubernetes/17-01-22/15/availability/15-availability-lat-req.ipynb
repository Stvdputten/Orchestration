# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/15/availability
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/15/availability/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/15/availability/../Figures'

# %%
# %env var=15
# %env var_name=availability
# %env exp=exp15

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=k8s

# !pwd
# !echo

# what to copy
# !cp ../k8s-$sn-* .
# !cp ../k8s-$mm-* .
# !cp ../k8s-$hr-* .

# !for file in k8s-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15
# env: var_name=availability
# env: exp=exp15
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=k8s
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/15/availability

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)latency-$orch-availability.png --nobox --lat_req k8s-* --legend_fontsize 20
# Out:
# Multiple benchmarks but one param
# Wrote: ../Figures/latency-k8s-availability.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

filename=f"{location}latency-{orch}-availability.png"
display(Image(filename=filename, retina=True))
