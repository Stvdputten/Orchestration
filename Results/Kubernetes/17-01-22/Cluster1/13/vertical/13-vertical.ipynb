# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/Cluster1/13/vertical
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/Cluster1/13/vertical/../Figures

# %%
# %env var=15
# %env var_name=vertical
# %env exp=exp13

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../k8s-$sn-* .
# !cp ../k8s-$mm-* .
# !cp ../k8s-$hr-* .

# !for file in k8s-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=15
# env: var_name=vertical
# env: exp=exp13
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Kubernetes/17-01-22/Cluster1/13/vertical
#
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R1000
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R10000
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R1500
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R2000
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R2500
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R3000
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R4000
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R500
# k8s-hr-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R6000
# k8s-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R1000
# k8s-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R2000
# k8s-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R3000
# k8s-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R4000
# k8s-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R500
# k8s-mm-wrk-compose-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R5000
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R10000
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R1500
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R2000
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R3000
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R4000
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R500
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R5000
# k8s-sn-wrk-mixed-c6525-25g-exp13-havail0-hori1-verti0-infi1-t4-c512-d30-R6000

# %%
# print which params to include
# !for file in k8s-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in k8s-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in k8s-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# R10000
# R1500
# R2000
# R3000
# R4000
# R500
# R5000
# R6000
# R1000
# R2000
# R3000
# R4000
# R500
# R5000
# R1000
# R10000
# R1500
# R2000
# R2500
# R3000
# R4000
# R500
# R6000

# %%
# rename to param(s)
# !for file in k8s-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in k8s-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in k8s-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/sn-vertical-exp13.png
# Wrote: ../Figures/mm-vertical-exp13.png
# Wrote: ../Figures/hr-vertical-exp13.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']

for bench in ['sn','mm','hr']:
    filename=f"{location}{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
