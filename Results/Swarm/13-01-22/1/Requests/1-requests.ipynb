# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# !cp ../swarm-sn-*-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-* .
# !cp ../swarm-mm-*-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-* .
# !cp ../swarm-hr-*-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-* .

# !for file in swarm-*; do echo $file; done
# Out:
# swarm-hr-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R1000
# swarm-hr-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R1500
# swarm-hr-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R2000
# swarm-hr-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R2500
# swarm-hr-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R3000
# swarm-hr-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R500
# swarm-mm-wrk-compose-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R1000
# swarm-mm-wrk-compose-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R1500
# swarm-mm-wrk-compose-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R2000
# swarm-mm-wrk-compose-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R2500
# swarm-mm-wrk-compose-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R3000
# swarm-mm-wrk-compose-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R500
# swarm-sn-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R1000
# swarm-sn-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R1500
# swarm-sn-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R2000
# swarm-sn-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R2500
# swarm-sn-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R3000
# swarm-sn-wrk-mixed-c6525-25g-exp1-havail0-hori1-verti1-infi1-client1-t4-c8-d30-R500

# %%
# %env var=f16

# !for file in swarm-sn-*; do mv $file sn-$(echo $file | cut -d- -$var) ; done  
# !for file in swarm-mm-*; do mv $file mm-$(echo $file | cut -d- -$var) ; done  
# !for file in swarm-hr-*; do mv $file hr-$(echo $file | cut -d- -$var) ; done
# Out:
# env: var=f16

# %%
# %env var_name=requests
# %env exp=exp1
# %env location=../Figures/

# !hdr-plot --output $(echo $location)sn-$var_name-$exp.png --nobox sn-*[^.png]
# !hdr-plot --output $(echo $location)mm-$var_name-$exp.png --nobox mm-*[^.png]
# !hdr-plot --output $(echo $location)hr-$var_name-$exp.png --nobox hr-*[^.png]
# Out:
# env: var_name=requests
# env: exp=exp1
# env: location=../Figures/
# Wrote: ../Figures/sn-requests-exp1.png
# Wrote: ../Figures/mm-requests-exp1.png
# Wrote: ../Figures/hr-requests-exp1.png

# %%
from IPython import display
import os
exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
display.Image(f"{location}sn-{var_name}-{exp}.png")

# %%
display.Image(f"{location}mm-{var_name}-{exp}.png")

# %%
display.Image(f"{location}hr-{var_name}-{exp}.png")
