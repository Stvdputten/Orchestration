# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/3/multiple-clients
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/3/multiple-clients/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/3/multiple-clients/../Figures'

# %%
# %env var=12-16
# %env var_name=clients
# %env exp=exp3
# %env location=../Figures/

# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=12-16
# env: var_name=clients
# env: exp=exp3
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/3/multiple-clients

# %%
# !hdr-plot --save --head swarm-*
# Out:
#    Latency  Requests  Throughput  Baseline  ...   Mean     Max  StdDev  ReqSec
# 0    10.59     200.0      5931.0         0  ...  3.383  12.400   2.240  197.26
# 1    10.79     200.0      5891.0         0  ...  3.380  14.200   2.286  195.93
# 2    10.45     200.0      5960.0         0  ...  3.347  13.144   2.236  198.32
# 3     5.76     200.0      5957.0         0  ...  4.328  14.504   0.667  198.16
# 4     5.69     200.0      5933.0         0  ...  4.353  48.704   1.179  197.36
#
# [5 rows x 18 columns]

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# client1-t8-c512-d30-R200
# client2-t8-c512-d30-R200
# client3-t8-c512-d30-R200
# client1-t8-c512-d30-R200
# client2-t8-c512-d30-R200
# client3-t8-c512-d30-R200
# client1-t8-c512-d30-R200
# client2-t8-c512-d30-R200
# client3-t8-c512-d30-R200

# %%
# rename to param(s)
# !for file in swarm-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-*
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-*
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-*
# Out:
# Wrote: ../Figures/sn-clients-exp3.png
# Wrote: ../Figures/mm-clients-exp3.png
# Wrote: ../Figures/hr-clients-exp3.png

# %%
from IPython import display
exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
display.Image(f"{location}sn-{var_name}-{exp}.png")

# %%
display.Image(f"{location}mm-{var_name}-{exp}.png")

# %%
display.Image(f"{location}hr-{var_name}-{exp}.png")
