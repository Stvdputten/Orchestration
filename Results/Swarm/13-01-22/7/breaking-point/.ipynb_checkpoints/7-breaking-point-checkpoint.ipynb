# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/6/nginx-16threads
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/6/nginx-16threads/../Figures

# %%
# %env var=13,16
# %env var_name=threads
# %env exp=exp6

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=13,16
# env: var_name=threads
# env: exp=exp6
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/6/nginx-16threads
#
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c1024-d30-R1500
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c1024-d30-R2000
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c1024-d30-R2500
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c1024-d30-R3000
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c1024-d30-R3500
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c512-d30-R1500
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c512-d30-R2000
# swarm-hr-wrk-mixed-c6525-25g-exp6-havail0-hori1-verti1-infi1-client1-t16-c512-d30-R2500
# ...

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# t16-R1500
# t16-R2000
# t16-R2500
# t16-R3000
# t16-R3500
# t16-R1500
# t16-R2000
# t16-R2500
# t16-R3000
# t16-R3500
# t8-R1500
# t8-R2000
# t8-R2500
# t8-R3000
# t8-R3500
# t8-R1500
# t8-R2000
# t8-R2500
# t8-R3000
# t8-R3500
# t16-R1500
# t16-R2000
# t16-R2500
# t16-R3000
# t16-R3500
# t16-R1500
# t16-R2000
# t16-R2500
# t16-R3000
# t16-R3500
# t8-R1500
# t8-R2000
# t8-R2500
# t8-R3000
# t8-R3500
# t8-R1500
# t8-R2000
# t8-R2500
# t8-R3000
# t8-R3500
# t16-R1500
# t16-R2000
# t16-R2500
# t16-R3000
# t16-R3500
# t16-R1500
# t16-R2000
# t16-R2500
# t16-R3000
# t16-R3500
# t8-R1500
# t8-R2000
# t8-R2500
# t8-R3000
# t8-R3500
# t8-R1500
# t8-R2000
# t8-R2500
# t8-R3000
# t8-R3500

# %%
# rename to param(s)
# !for file in swarm-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# %env var_name=t8
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-$var_name-* --legend_fontsize 16
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-$var_name-* --legend_fontsize 16
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-$var_name-* --legend_fontsize 16

# %env var_name=t16
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-$var_name-* --legend_fontsize 16
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-$var_name-* --legend_fontsize 16
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-$var_name-* --legend_fontsize 16
# Out:
# env: var_name=t8
# Wrote: ../Figures/sn-t8-exp6.png
# Wrote: ../Figures/mm-t8-exp6.png
# Wrote: ../Figures/hr-t8-exp6.png
# env: var_name=t16
# Wrote: ../Figures/sn-t16-exp6.png
# Wrote: ../Figures/mm-t16-exp6.png
# Wrote: ../Figures/hr-t16-exp6.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']

for bench in ['sn','mm','hr']:
    for threads in [8,16]:
        print(bench)
        print(threads)
        filename=f"{location}{bench}-t{threads}-{exp}.png"
        display(Image(filename=filename, retina=True))
# Out:
# sn
# 8
# sn
# 16
# mm
# 8
# mm
# 16
# hr
# 8
# hr
# 16
