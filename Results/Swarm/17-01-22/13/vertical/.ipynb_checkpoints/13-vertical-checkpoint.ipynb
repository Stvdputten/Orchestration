# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/12/baseline-stress
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/12/baseline-stress/../Figures

# %%
# %env var=13,14,16
# %env var_name=baseline-stress
# %env exp=exp12

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=13,14,16
# env: var_name=baseline-stress
# env: exp=exp12
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# /Users/stvdputten/Documents/Thesis/Results/Swarm/13-01-22/12/baseline-stress
#
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R12000
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R14000
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R16000
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R18000
# swarm-hr-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R20000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R5000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R6000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R7000
# swarm-mm-wrk-compose-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R8000
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R1500
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R4000
# swarm-sn-wrk-mixed-c6525-25g-exp12-havail0-hori1-verti1-infi1-client1-t4-c512-d30-R5000

# %%
# print which params to include
# !for file in swarm-$sn-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$mm-*; do echo $file | cut -d- -f $var ; done
# !for file in swarm-$hr-*; do echo $file | cut -d- -f $var ; done
# Out:
# t4-c512-R1500
# t4-c512-R2000
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R5000
# t4-c512-R3000
# t4-c512-R4000
# t4-c512-R5000
# t4-c512-R6000
# t4-c512-R7000
# t4-c512-R8000
# t4-c512-R12000
# t4-c512-R14000
# t4-c512-R16000
# t4-c512-R18000
# t4-c512-R20000

# %%
# rename to param(s)
# !for file in swarm-$sn-*; do mv $file $sn-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$mm-*; do mv $file $mm-$(echo $file | cut -d- -f $var) ; done
# !for file in swarm-$hr-*; do mv $file $hr-$(echo $file | cut -d- -f $var) ; done

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)$sn-$var_name-$exp.png --nobox $sn-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$mm-$var_name-$exp.png --nobox $mm-* --legend_fontsize 20
# !hdr-plot --output $(echo $location)$hr-$var_name-$exp.png --nobox $hr-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/sn-baseline-stress-exp12.png
# Wrote: ../Figures/mm-baseline-stress-exp12.png
# Wrote: ../Figures/hr-baseline-stress-exp12.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']

for bench in ['sn','mm','hr']:
    filename=f"{location}{bench}-{var_name}-{exp}.png"
    display(Image(filename=filename, retina=True))
