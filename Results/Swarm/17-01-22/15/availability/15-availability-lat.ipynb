# %%
import os
cwd = os.getcwd()
print(cwd)
directory = "../Figures"
path = os.path.join(cwd, directory) 
print(path)
try: 
    os.mkdir(path) 
except OSError as error: 
    print(error)
# Out:
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/15/availability
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/15/availability/../Figures
# [Errno 17] File exists: '/Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/15/availability/../Figures'

# %%
# %env var=16
# %env var_name=availability
# %env exp=exp15

# %env location=../Figures/
# %env sn=sn
# %env mm=mm
# %env hr=hr
# %env orch=swarm

# !pwd
# !echo

# what to copy
# !cp ../swarm-$sn-* .
# !cp ../swarm-$mm-* .
# !cp ../swarm-$hr-* .

# !for file in swarm-* ; do echo $file; done  
# !for file in swarm-sn-*-R500 ; do echo $file; done
# Out:
# env: var=16
# env: var_name=availability
# env: exp=exp15
# env: location=../Figures/
# env: sn=sn
# env: mm=mm
# env: hr=hr
# env: orch=swarm
# /Users/stvdputten/Documents/Thesis/Results/Swarm/17-01-22/15/availability
#
# swarm-hr-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R1000
# swarm-hr-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R1500
# swarm-hr-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-hr-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R2500
# swarm-hr-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-hr-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R500
# swarm-mm-wrk-compose-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R1000
# swarm-mm-wrk-compose-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-mm-wrk-compose-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R500
# swarm-sn-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R1500
# swarm-sn-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R2000
# swarm-sn-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R3000
# swarm-sn-wrk-mixed-c6525-25g-exp15-havail1-hori1-verti1-infi1-client1-t4-c512-d30-R500

# %%
# Overview of all
# %env var_name=t16-c512
# !hdr-plot --output $(echo $location)lat-$orch-$var_name-$exp.png --nobox --lat_req swarm-* --legend_fontsize 20
# Out:
# Wrote: ../Figures/lat-swarm-availability-exp15.png

# %%
from IPython.display import display, Image

exp=os.environ['exp']
var_name=os.environ['var_name']
location=os.environ['location']
orch=os.environ['orch']

filename=f"{location}lat-{orch}-{var_name}-{exp}.png"
display(Image(filename=filename, retina=True))
